# %% [markdown]
# # Occupation

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %% [markdown]
# ### Step 3. Assign it to a variable called users.

# %%
occupation=pd.read_csv("occupation.csv",sep="|")
occupation.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %% [markdown]
# ### Step 4. Discover what is the mean age per occupation

# %%
occupation.groupby("occupation")["age"].mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# ### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
data=pd.DataFrame(occupation.groupby("occupation")["gender"].value_counts()/occupation["gender"].value_counts()*50)
data.sort_values(by=["gender"],ascending=False)
# Out:
#                           count
# occupation    gender
# administrator M        3.208955
# healthcare    M        0.373134
# writer        M        1.940299
# technician    M        1.940299
# student       M       10.149254
# scientist     M        2.089552
# salesman      M        0.671642
# retired       M        0.970149
# programmer    M        4.477612
# other         M        5.149254
# none          M        0.373134
# marketing     M        1.194030
# lawyer        M        0.746269
# homemaker     M        0.074627
# librarian     M        1.641791
# engineer      M        4.850746
# artist        M        1.119403
# executive     M        2.164179
# doctor        M        0.522388
# educator      M        5.149254
# entertainment M        1.194030
# homemaker     F        1.098901
# technician    F        0.183150
# artist        F        2.380952
# student       F       10.989011
# scientist     F        0.549451
# salesman      F        0.549451
# ...

# %% [markdown]
# ### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
occupation.groupby("occupation")["age"].agg(["min","max"]).sort_values(by=["min","max"],ascending=False)
# Out:
#                min  max
# occupation
# retired         51   73
# doctor          28   64
# marketing       24   55
# librarian       23   69
# educator        23   63
# scientist       23   55
# engineer        22   70
# executive       22   69
# healthcare      22   62
# administrator   21   70
# technician      21   55
# lawyer          21   53
# programmer      20   63
# homemaker       20   50
# artist          19   48
# salesman        18   66
# writer          18   60
# entertainment   15   50
# other           13   64
# none            11   55
# student          7   42

# %% [markdown]
# ### Step 7. For each combination of occupation and gender, calculate the mean age

# %%
occupation.groupby(['occupation', 'gender'])["age"].mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %% [markdown]
# ### Step 8.  For each occupation present the percentage of women and men

# %%
# create a data frame and apply count to gender
gender_ocup = occupation.groupby(['occupation', 'gender']).agg({'gender': 'count'})

# create a DataFrame and apply count for each occupation
occup_count = occupation.groupby(['occupation']).agg('count')

# divide the gender_ocup per the occup_count and multiply per 100
occup_gender = gender_ocup.div(occup_count, level = "occupation") * 100

# present all rows from the 'gender column'
occup_gender.loc[: , 'gender']
# Out:
# occupation     gender
# administrator  F          45.569620
#                M          54.430380
# artist         F          46.428571
#                M          53.571429
# doctor         M         100.000000
# educator       F          27.368421
#                M          72.631579
# engineer       F           2.985075
#                M          97.014925
# entertainment  F          11.111111
#                M          88.888889
# executive      F           9.375000
#                M          90.625000
# healthcare     F          68.750000
#                M          31.250000
# homemaker      F          85.714286
#                M          14.285714
# lawyer         F          16.666667
#                M          83.333333
# librarian      F          56.862745
#                M          43.137255
# marketing      F          38.461538
#                M          61.538462
# none           F          44.444444
#                M          55.555556
# ...
